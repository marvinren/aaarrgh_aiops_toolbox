# %%
from change_detection.cusum.cusum_change_point_detection import CUSUMChangeDetection
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.facecolor'] = 'white'
plt.style.use("seaborn-darkgrid")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x = np.random.randn(300)/5
x[100:200] += np.arange(0, 4, 4/100)
model = CUSUMChangeDetection(5, 0.02, True)
model.fit_predict(x)
model.plot()

# %%
print(model._ta)
# Out:
# []

# %%
x = np.random.randn(300)
x[100:200] += 6
model = CUSUMChangeDetection(4, 1.5, True)
model.fit_predict(x)
model.plot()

# %%
x = 2*np.sin(2*np.pi*np.arange(0, 3, .01))
model = CUSUMChangeDetection(1, 0.05, True)
model.fit_predict(x)
model.plot()

# %%
x = np.random.randn(10000)
x[400:600] += 6
print('Detection of onset (data size = %d):' %x.size)
model = CUSUMChangeDetection(6, 1.5, True)
# %timeit model.fit_predict(x)
model.plot()
# Out:
# Detection of onset (data size = 10000):
# 24.5 ms ± 150 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': True,
# ...
